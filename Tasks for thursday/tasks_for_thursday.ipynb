# %% [markdown]
# **My dataaqusition class**

# %%
from Data_aqu import dataaquisition

# %% [markdown]
# **task 1**

# %%
#the data extraxtion part
getdata = dataaquisition()
getdata.generatedata()
data1, data2 = getdata.getdata()
print(data1)
print(data2)
# Out:
# [77.43894186593174, 146.0026918312127, 106.08230832450042, 104.26672959775559, 109.659035111952, 102.8248680149792, 118.71801199039894, 100.48697807355508, 101.86931035028542, 116.23266502736804, 93.05769629370866, 86.54122505681535, 90.04530380379911, 96.43991834531037, 98.69318426130336, 129.08890103159774, 109.4901221464005, 114.59857156620238, 103.88483526904034, 96.17983397882522, 99.82512515453033, 96.42312573669993, 82.25029911259104, 92.80807265438085, 80.60009965547269, 90.35594676455659, 71.2414211339073, 121.56150918530818, 123.29202848458586, 108.22024472932958, 93.08213360641554, 90.48352949519023, 96.4827781552373, 87.86514549208763, 82.74034880065068, 89.40526785948222, 91.39239907935863, 98.62453234218204, 107.58141190019194, 102.26104801461942, 105.92635159927217, 95.5995553854739, 94.14272593418922, 83.2344843566951, 104.55219237092182, 125.081783702518, 96.16367760270919, 100.59952043124414, 105.56610760741802, 96.73808945631325, 120.19362289675942, 73.611349929888
# ...

# %%
#the plotting part

#plotting data1
plt.figure()
plt.hist(data1,bins=30)
plt.xlabel("data1")
plt.ylabel("frequency")

#plotting data2
plt.figure()
plt.hist(data2,bins=30)
plt.xlabel("data2")

#plotting data1 vs data2
plt.figure()
plt.scatter(data1,data2)
plt.xlabel("data1")
plt.ylabel("data2")
plt.title("plot of data1 vs data2")
plt.show()

# %% [markdown]
# **Task 3**

# %%
daq = dataaquisition(n=1000)
daq.generatedata()
daq.plot_heatmap()

# %% [markdown]
# **Task 3**

# %%
daq = dataaquisition()
counts, edges = daq.histogram_from_file("heights.csv")

# %% [markdown]
# **task 4**

# %%
pmf = daq.pmf_from_counts(counts)
daq.plot_pmf(pmf, title="PMF from heights.csv")

# %% [markdown]
# **task 5**

# %%
cs = daq.cumulative_from_pmf(pmf)                    
print(cs)
# Out:
# [0.02 0.08 0.17 0.32 0.51 0.67 0.78 0.88 0.97 1.  ]
